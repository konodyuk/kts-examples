# %% [markdown]
# # `kts` Workflow
# ## Feature Engineering

# %%
# %pylab inline
import pandas as pd
import kts
from kts import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Let's read the data and save it to kts storage for faster access. We need to set `PassengerId` as index as kts assumes each object has a unique index.

# %%
# %%time
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')
train.set_index('PassengerId', inplace=True)
test.set_index('PassengerId', inplace=True)
test['Survived'] = -1
kts.save(train, 'train')
kts.save(test, 'test')
# Out:
# CPU times: user 30 ms, sys: 6.67 ms, total: 36.7 ms
# Wall time: 39.9 ms

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# Now let's do some feature engineering. Each function should produce a block of new and uniquely named features and have one argument: an initial dataframe (`train` in this case). We can preview our feature constructor with `@preview(df_name, [sizes_to_eval])`:

# %%
@preview(train)
def family_size(df):
    res = stl.empty_like(df)
    res['family_sz'] = df['SibSp'] + df['Parch'] + 1
    res['is_alone'] = (res['family_sz'] == 1).astype(int)
    return res
# Out:
#              family_sz  is_alone
# PassengerId
# 1                    2         0
# 2                    2         0
#              family_sz  is_alone
# PassengerId
# 1                    2         0
# 2                    2         0
# 3                    1         1
# 4                    2         0
#              family_sz  is_alone
# PassengerId
# 1                    2         0
# 2                    2         0
# 3                    1         1
# 4                    2         0
# 5                    1         1
# 6                    1         1

# %%
@preview(train, [10])
def family_size(df):
    res = stl.empty_like(df)
    res['family_sz'] = df['SibSp'] + df['Parch'] + 1
    res['is_alone'] = (res['family_sz'] == 1).astype(int)
    return res
# Out:
#              family_sz  is_alone
# PassengerId
# 1                    2         0
# 2                    2         0
# 3                    1         1
# 4                    2         0
# 5                    1         1
# 6                    1         1
# 7                    1         1
# 8                    5         0
# 9                    3         0
# 10                   2         0

# %% [markdown]
# When we're sure the function works fine, we can `@register` it. Of course, in a real project we would preview and register a function at the same cell.

# %%
@register
def family_size(df):
    res = stl.empty_like(df)
    res['family_sz'] = df['SibSp'] + df['Parch'] + 1
    res['is_alone'] = (res['family_sz'] == 1).astype(int)
    return res

# %% [markdown]
# Now the function is saved in `kts.features` list and can be defined in any notebook with `features.define_in_scope(globals())`, check `Modelling.ipynb` for reference.

# %%
features
# Out:
# [family_size]

# %% [markdown]
# kts has a standard library of simple feature generators:
# * `stl.discretize(columns, n_bins)`
# * `stl.discretize_quantile(columns, n_bins)`
# * `stl.target_encoding(columns_to_encode, target_columns, aggregation)`
# * `stl.make_ohe(columns)`
#
# and some service functors:
# * `stl.empty_like(df)` - return only index of a dataframe
# * `stl.identity(df)` - return the same dataframe
# * `stl.concat([func1, func2])(df)` - create features with `func1` and `func2`, and merge them
# * `stl.compose([func1, func2])(df)` - apply `func1` and `func2` to `df` sequentially

# %%
stl.empty_like(train.head(2))
stl.identity(train.head(2))
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 2]
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# We can use previously created features to create new. You may want to use preview with different sizes of input dataframe to ensure that target encoding works fine:

# %%
@preview(train, [20, 30])
def family_size_encode(df):
    tmp = family_size(df)
    tmp['Survived'] = df['Survived']
    return stl.concat([
        stl.target_encoding(['family_sz', 'is_alone'], 'Survived'),
        stl.make_ohe(['family_sz', 'is_alone'])
    ])(tmp)
# Out:
#              family_sz_te_Survived_mean  is_alone_te_Survived_mean  \
# PassengerId
# 1                                   0.6                        0.5
# 2                                   0.6                        0.5
# 3                                   0.5                        0.5
# 4                                   0.6                        0.5
# 5                                   0.5                        0.5
# 6                                   0.5                        0.5
# 7                                   0.5                        0.5
# 8                                   0.0                        0.5
# 9                                   1.0                        0.5
# 10                                  0.6                        0.5
# 11                                  1.0                        0.5
# 12                                  0.5                        0.5
# 13                                  0.5                        0.5
# 14                                  0.0                        0.5
# 15                                  0.5                        0.5
# 16                                  0.5                        0.5
# 17                                  0.0                        0.5
# 18                                  0.5                        0.5
# 19                                  0.6                        0.5
# 20                                  0.5                        0.5
#
#              family_sz_ohe_1  family_sz_ohe_2  family_sz_ohe_3  \
# PassengerId
# 1                          0                1                0
# 2                          0                1                0
# 3                          1                0                0
# 4                          0                1                0
# 5                          1                0                0
# 6                          1                0                0
# 7                          1                0                0
# 8                          0                0                0
# 9                          0                0                1
# 10                         0                1                0
# 11                         0                0                1
# 12                         1                0                0
# 13                         1                0                0
# 14                         0                0                0
# 15                         1                0                0
# 16                         1                0                0
# 17                         0                0                0
# 18                         1                0                0
# 19                         0                1                0
# 20                         1                0                0
#
#              family_sz_ohe_5  family_sz_ohe_6  family_sz_ohe_7  \
# PassengerId
# 1                          0                0                0
# 2                          0                0                0
# 3                          0                0                0
# 4                          0                0                0
# 5                          0                0                0
# 6                          0                0                0
# 7                          0                0                0
# 8                          1                0                0
# 9                          0                0                0
# 10                         0                0                0
# 11                         0                0                0
# 12                         0                0                0
# 13                         0                0                0
# 14                         0                0                1
# 15                         0                0                0
# 16                         0                0                0
# 17                         0                1                0
# 18                         0                0                0
# 19                         0                0                0
# 20                         0                0                0
#
#              is_alone_ohe_0  is_alone_ohe_1
# PassengerId
# 1                         1               0
# 2                         1               0
# 3                         0               1
# 4                         1               0
# 5                         0               1
# 6                         0               1
# 7                         0               1
# 8                         1               0
# 9                         1               0
# 10                        1               0
# 11                        1               0
# 12                        0               1
# 13                        0               1
# 14                        1               0
# 15                        0               1
# 16                        0               1
# 17                        1               0
# 18                        0               1
# 19                        1               0
# 20                        0               1
#              family_sz_te_Survived_mean  is_alone_te_Survived_mean  \
# PassengerId
# 1                              0.600000                   0.461538
# 2                              0.600000                   0.461538
# 3                              0.529412                   0.529412
# 4                              0.600000                   0.461538
# 5                              0.529412                   0.529412
# 6                              0.529412                   0.529412
# 7                              0.529412                   0.529412
# 8                              0.000000                   0.461538
# 9                              1.000000                   0.461538
# 10                             0.600000                   0.461538
# 11                             1.000000                   0.461538
# 12                             0.529412                   0.529412
# 13                             0.529412                   0.529412
# 14                             0.500000                   0.461538
# 15                             0.529412                   0.529412
# 16                             0.529412                   0.529412
# 17                             0.000000                   0.461538
# 18                             0.529412                   0.529412
# 19                             0.600000                   0.461538
# 20                             0.529412                   0.529412
# 21                             0.529412                   0.529412
# 22                             0.529412                   0.529412
# 23                             0.529412                   0.529412
# 24                             0.529412                   0.529412
# 25                             0.000000                   0.461538
# 26                             0.500000                   0.461538
# 27                             0.529412                   0.529412
# 28                             0.000000                   0.461538
# 29                             0.529412                   0.529412
# 30                             0.529412                   0.529412
#
#              family_sz_ohe_1  family_sz_ohe_2  family_sz_ohe_3  \
# PassengerId
# 1                          0                1                0
# 2                          0                1                0
# 3                          1                0                0
# 4                          0                1                0
# 5                          1                0                0
# 6                          1                0                0
# 7                          1                0                0
# 8                          0                0                0
# 9                          0                0                1
# 10                         0                1                0
# 11                         0                0                1
# 12                         1                0                0
# 13                         1                0                0
# 14                         0                0                0
# 15                         1                0                0
# 16                         1                0                0
# 17                         0                0                0
# 18                         1                0                0
# 19                         0                1                0
# 20                         1                0                0
# 21                         1                0                0
# 22                         1                0                0
# 23                         1                0                0
# 24                         1                0                0
# 25                         0                0                0
# 26                         0                0                0
# 27                         1                0                0
# 28                         0                0                0
# 29                         1                0                0
# 30                         1                0                0
#
#              family_sz_ohe_5  family_sz_ohe_6  family_sz_ohe_7  \
# PassengerId
# 1                          0                0                0
# 2                          0                0                0
# 3                          0                0                0
# 4                          0                0                0
# 5                          0                0                0
# 6                          0                0                0
# 7                          0                0                0
# 8                          1                0                0
# 9                          0                0                0
# 10                         0                0                0
# 11                         0                0                0
# 12                         0                0                0
# 13                         0                0                0
# 14                         0                0                1
# 15                         0                0                0
# 16                         0                0                0
# 17                         0                1                0
# 18                         0                0                0
# 19                         0                0                0
# 20                         0                0                0
# 21                         0                0                0
# 22                         0                0                0
# 23                         0                0                0
# 24                         0                0                0
# 25                         1                0                0
# 26                         0                0                1
# 27                         0                0                0
# 28                         0                1                0
# 29                         0                0                0
# 30                         0                0                0
#
#              is_alone_ohe_0  is_alone_ohe_1
# PassengerId
# 1                         1               0
# 2                         1               0
# 3                         0               1
# 4                         1               0
# 5                         0               1
# 6                         0               1
# 7                         0               1
# 8                         1               0
# 9                         1               0
# 10                        1               0
# 11                        1               0
# 12                        0               1
# 13                        0               1
# 14                        1               0
# 15                        0               1
# 16                        0               1
# 17                        1               0
# 18                        0               1
# 19                        1               0
# 20                        0               1
# 21                        0               1
# 22                        0               1
# 23                        0               1
# 24                        0               1
# 25                        1               0
# 26                        1               0
# 27                        0               1
# 28                        1               0
# 29                        0               1
# 30                        0               1

# %%
@register
def family_size_encode(df):
    tmp = family_size(df)
    tmp['Survived'] = df['Survived']
    return stl.concat([
        stl.target_encoding(['family_sz', 'is_alone'], 'Survived'),
        stl.make_ohe(['family_sz', 'is_alone'])
    ])(tmp)

# %% [markdown]
# And let's create a bit more features:

# %%
# @preview(train, [200])
@register
def encode_age_and_sex(df):
    tmp = stl.discretize(['Age'], 5)(df)
    tmp['Sex'] = df['Sex']
    tmp['Survived'] = df['Survived']
    return stl.concat([
        stl.target_encoding(['disc_5_Age', 'Sex'], 'Survived'),
        stl.make_ohe(['disc_5_Age', 'Sex'])
    ])(tmp)

# %%
# @preview(train)
@register
def select_numeric(df):
    res = stl.column_selector(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'])(df)
    return res.fillna(-1)

# %% [markdown]
# Now we are ready to train our first model in `ModelingStart.ipynb`.
